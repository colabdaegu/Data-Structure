# %%
def section_sort(A):
    n = len(A)
    for i in range(n-1):
        least = i
        for j in range(i+1, n):
            if(A[j] < A[least]):
                least = j
        A[i], A[least] = A[least], A[i]

    print(A)

# %%
def selection_sort(A) :      #선택 정렬 함수
    n = len(A)               #입력 리스트의 크기(길이)를 구한다.
    for i in range(n-1) :    
        least = i           #가장 작은 값의 인덱스 
        for j in range(i+1, n) : #정렬되지 않은 리스트에서 가장 작은 값 찾기
            if (A[j] < A[least]) : #두 값의 비교
                least = j        #더 작은 값의 인덱스로 least 갱신
        A[i], A[least] = A[least], A[i] #위치 이동(값 교환)        
        
        print(A);

# %%
my_list = [3, 2, 1]
print("input list:", my_list)
selection_sort(my_list)
print("sorted list:", my_list)

# %%
my_list = [1, 3, 2]
print("input list:", my_list)
selection_sort(my_list)
print("sorted list:", my_list)

# %%
my_list = [1, 2, 3]
print("input list:", my_list)
selection_sort(my_list)
print("sorted list:", my_list)

# %%
print(" 선택 정렬의 예")
my_list = [6,5,10,3,12,1,2,4,19]
print("input list:", my_list)
selection_sort(my_list)
print("sorted list:", my_list)

# %%
def selection_sort(A) :      #선택 정렬 함수
    n = len(A)               #입력 리스트의 크기(길이)를 구한다.
   # count 초기화
    count = 0
    for i in range(n-1) :    
        least = i           #가장 작은 값의 인덱스 
        for j in range(i+1, n) : #정렬되지 않은 리스트에서 가장 작은 값 찾기
            #count 1증가
            count += 1
            if (A[j] < A[least]) : #두 값의 비교
                least = j        #더 작은 값의 인덱스로 least 갱신
        A[i], A[least] = A[least], A[i] #위치 이동(값 교환)        
        
        #print(A);
    #count 보기
    print(count);

# %%
n = 100000
my_list = list(range(n))
selection_sort(my_list)

# %%
print(" 선택 정렬의 예")
my_list = list('eacdb')
print("input list:", my_list)
selection_sort(my_list)
print("sorted list:", my_list)

# %%
def selection_sort(A) :      #선택 정렬 함수
    n = len(A)               #입력 리스트의 크기(길이)를 구한다.
    for i in range(n-1) :    
        least = i           #가장 작은 값의 인덱스 
        for j in range(i+1, n) : #정렬되지 않은 리스트에서 가장 작은 값 찾기
            if (A[j] < A[least]) : #두 값의 비교
                least = j        #더 작은 값의 인덱스로 least 갱신
        A[i], A[least] = A[least], A[i] #위치 이동(값 교환)        
        
        print(A);

# %%
print(" 선택 정렬의 예")
my_list = [6,5,10,3,12,1,2,4,19]
print("input list:", my_list)
selection_sort(my_list)
print("sorted list:", my_list)

print(" 선택 정렬의 예")
my_list = list('eacdb')
print("input list:", my_list)
selection_sort(my_list)
print("sorted list:", my_list)

# %% [markdown]
# # 삽입 정렬

# %%
def insertion_sort(A):          #삽입 정렬 함수
    n = len(A)                  #입력 리스트의 크기(길이)를 구한다.
    for i in range(1, n):        
        temp = A[i]            #정렬 대상 값 
        j = i
        while j > 0 and A[j-1] > temp:  #앞쪽으로 비교해 나간다.
            A[j] = A[j-1]    #더 큰 값은 뒤쪽으로 이동시킨다.
            j -= 1
        A[j] = temp           #정렬 대상 값의 위치에 삽입한다.
        
        print(A)
        

my_list = [6,5,10,3,12,1,2,4,19]
print("input list:", my_list)
print("********")
print(" 삽입 정렬의 예")
insertion_sort(my_list)
print("sorted list:", my_list)
my_list = [6,5,10,3,12,1,2,4,19]
print(" 선택 정렬의 예")
selection_sort(my_list)
print("sorted list:", my_list)
print("********")

print(" 삽입 정렬의 예")
my_list = list('eacdb')
print("input list:", my_list)
insertion_sort(my_list)
print("sorted list:", my_list)
